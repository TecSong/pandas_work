# %% [markdown]
# ``## Weather data
#
# The US has a long history of weather measurements. This history leads to its data often stored in an older format. Specifically, we're going to look at the data from [US Historical Climatology Network (USHCN)](https://www.ncei.noaa.gov/products/land-based-station/us-historical-climatology-network).

# %% [markdown]
# ## Task 1 - Parsing an old file
#
# We've downloaded the file corresponding to the weather stations, `ushcn-v2.5-stations.txt`. Please store this properly into a data frame called "`stations`". Properly means each row is a station and each variable is a different column.
#
# - Please remember to use the `with open(...):` syntax to read this file.
# - Please keep the original column names from the `readme.txt` file except for the text inside parentases.
# - There's actually a typo in the documentation below (and in the readme.txt), please correct this when reading the file. Hint: given this format, the most space between 2 variables to visually separate them should be at most a single space.
# - Please do not include the text in `()` in your variable name.
#
# In the [readme.txt](https://www.ncei.noaa.gov/pub/data/ushcn/v2.5/readme.txt) from USHCN, we know that the data corresponds to specific locations on a line, e.g. the first 2 characters in the line correspond to the "Country Code" variable.
#
# ```
# STATION LIST AND DATA FORMATS
#
# 	FORMAT OF "ushcn-v2.5-stations.txt"
#
# 	----------------------------------------
# 	Variable             Columns    Type
# 	----------------------------------------
# 	COUNTRY CODE             1-2    Character
# 	NETWORK CODE               3    Character
# 	ID PLACEHOLDERS ("00")   4-5    Character
# 	COOP ID                 6-11    Character
# 	LATITUDE               13-20    Real
# 	LONGITUDE              22-30    Real
# 	ELEVATION              33-37    Real
# 	STATE                  39-40    Character
# 	NAME                   42-71    Character
# 	COMPONENT 1 (COOP ID)  73-78    Character
# 	COMPONENT 2 (COOP ID)  80-85    Character
# 	COMPONENT 3 (COOP ID)  87-92    Character
# 	UTC OFFSET             94-95    Integer
# 	-----------------------------------------
# ```
#
# Hints:
# - Read a variable using subsetting with strings
# - You may want to write the `readme.txt` information into a dictionary then use that somehow.
# - If you write a function, you could just loop over each line.

# %%
### TEST FUNCTION: test_stations
# DO NOT REMOVE THE LINE ABOVE
from pandas import Series, DataFrame
import pandas as pd
for i in range(1,14):
    a="x"+str(i)
    exec(a+'= %r' % [])
def cla (s):
    x1.append(s[0:2])
    x2.append(s[2:3])
    x3.append(s[3:5])
    x4.append(s[5:11])
    x5.append(s[12:20])
    x6.append(s[21:30])
    x7.append(s[31:37])
    x8.append(s[38:40])
    x9.append(s[41:71])
    x10.append(s[72:78])
    x11.append(s[79:85])
    x12.append(s[86:92])
    x13.append(s[93:95])



with open('./ushcn-v2.5-stations.txt') as ff:
    doc1=ff.read().split("\n")
    
    for i in range(0,1218):
        cla(doc1[i])
    x=[x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13]
    stations=DataFrame(x).T
    stations.columns=["COUNTRY CODE","NETWORK CODE",
    "ID PLACEHOLDERS","COOP ID","LATITUDE","LONGITUDE","ELEVATION",
    "STATE","NAME","COMPONENT 1","COMPONENT 2",
    "COMPONENT 3","UTC OFFSET"]
    print(stations['ELEVATION'])
# Out:
# 0         25.9
# 1          7.0
# 2         38.1
# 3         67.1
# 4        132.0
#          ...
# 1213    1143.0
# 1214    1249.1
# 1215    1413.7
# 1216    1237.5
# 1217    1898.9
# Name: ELEVATION, Length: 1218, dtype: object

# %% [markdown]
# ## Task 2 - plotting the locations
#
# Please plot the locations of these stations using `seaborn.scatterplot()`. Please remember to label your x and y axes.
#
# Side comment: on an exam I would ask you to provide a piece of insight from this plot. For example, relative to a perfect dataset, what seems to be missing in this plot?

# %%
### TEST FUNCTION: test_plot
# DO NOT REMOVE THE LINE ABOVE

# %% [markdown]
# ## Task 3 - Wide format data to long format
#
# In the file `hw3_tmax.csv`, we have the daily maximum temperature averaged over each month for a particular station. The details about the variables are in the [readme.txt](https://www.ncei.noaa.gov/pub/data/ushcn/v2.5/readme.txt) file but you shouldn't worry too much about that here.
#
# This dataset is stored in the "wide format" which is more compact but hard to use. Specifically, each year is a row where each month's tmax and its corresponding data quality flags are labeled `"value{?}", "dsflag{?}", "qcflag{?}", "dmflag{?}"` as different columns, where `{?}` would be the month number.
#
# The long format on the other hand is more compatible with models and graphing libraries where each row corresponds to a single unit.
#
# Please wrangle the data so
# - Each row is a single year-month measurement.
# - All -9999 values should be replaced with NaN. Empty strings, i.e. `""`, imply the quality is good, do NOT replace those with NaN.
# - The columns should be `id`, `year`, `month`, `tmax`, `dmflag`, `qcflag`, and `dsflag` (in any order).
# - Do not remove any months in the original data even if the values are NaN.
# - Sort the data so the earliest data is at the top of the data frame.
# - Make sure the `tmax` column is in Celsius (you need to read the readme.txt to know how to do this)
# - The new data frame should be called `"ldf"` as in "long data frame".

# %%
### TEST FUNCTION: test_wrangle_wide2long
# DO NOT REMOVE THE LINE ABOVE
